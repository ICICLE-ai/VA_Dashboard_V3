# %%
import pandas as pdt
import numpy as np 
import rdflib 
from rdflib import Namespace 
import yaml
import networkx as nx

# %%
class Test():
    def __init__(self):
        self.mappedEntities = mappedEntities = [{'type': 'target', 'entity': 'collaborators', 'class': ['Person']}, {'type': 'filtering', 'entity': 'water quality', 'class': ['Project', 'Dataset'], 'related': [{'text': 'Water Quality & Watersheds Program', 'entity': 'https://raw.githubusercontent.com/adhollander/FSLschemas/main/CA_PPODterms.ttl#prg_c46c0b', 'class': 'http://vivoweb.org/ontology/core#Program', 'idx': 5134, 'color': '#d73027'}, {'text': 'Nitrate Groundwater Pollution Hazard Index', 'entity': 'https://raw.githubusercontent.com/adhollander/FSLschemas/main/CA_PPODterms.ttl#tol_b14e38', 'class': 'http://www.sdsconsortium.org/schemas/sds-okn.owl#Tool', 'idx': 6775, 'color': '#d73027'}, {'text': 'Safe Drinking Water, Water Quality and Supply, Flood Control, River and Coastal Protection Bond Act of 2006', 'entity': 'https://raw.githubusercontent.com/adhollander/FSLschemas/main/CA_PPODterms.ttl#gmt_3b0a8a', 'class': 'http://www.sdsconsortium.org/schemas/sds-okn.owl#BestPracticesAndMandates', 'idx': 155, 'color': '#d73027'}, {'text': 'Water Resources Specialist', 'entity': 'https://raw.githubusercontent.com/adhollander/FSLschemas/main/CA_PPODterms.ttl#rol_9b72be', 'class': 'http://purl.obolibrary.org/obo/BFO_0000023', 'idx': 6344, 'color': '#d73027'}, {'text': 'Advanced Water Purification Facility', 'entity': 'https://raw.githubusercontent.com/adhollander/FSLschemas/main/CA_PPODterms.ttl#inf_1640d2', 'class': 'https://raw.githubusercontent.com/adhollander/FSLschemas/main/sustsource.owl#Infrastructure', 'idx': 605, 'color': '#d73027'}, {'text': 'Healthy Watersheds', 'entity': 'https://raw.githubusercontent.com/adhollander/FSLschemas/main/CA_PPODterms.ttl#prg_24edc1', 'class': 'http://vivoweb.org/ontology/core#Program', 'idx': 4982, 'color': '#d73027'}]}]
        self.data = pd.read_csv('../data/nodes_info.csv')
        self.phraseEmbs = np.load('../data/node_phrasebert_embeddings.npy')
        self.linkml, self.g  = self.readKG("../data/PPOD.yaml", "../data/PPOD_CA.ttl")
        self.ont = nx.read_graphml('../data/ontology_ppod.graphml')
        self.relevantEntId = [5134, 4982, 5021, 5043, 5648]
    def readKG(self, file1, file2):
        g = rdflib.Graph()
        g.parse(file2, format="turtle")
        with open(file1, 'r') as file:
            linkml = yaml.safe_load(file)
            prefix = linkml['prefixes']
            for ele in prefix:
                g.bind(ele, Namespace(prefix[ele]))
            return linkml, g 
    def getPath(self, source, target):
        """
        It will return a sequence of nodes, from source to target.
        """
        return nx.shortest_path(self.ont, source, target)
    def getRelName(self, source, target ):
        return eval(self.ont[source][target]['relation']) ## converting it to list 

    def getRelURI(self, name):
        return self.linkml['slots'][name]['slot_uri']

    def getTargetEntities(self, node_class, target_class, node_id):
        graph = []
        for target in target_class: 
            path_query = "?startNode "
            p = self.getPath(node_class, target)
            print(p)
            for i in range(1, len(p)): ## adding one path 
                rels = self.getRelName(p[i-1], p[i])
                print(rels)
                one_path_query = "("
                for one_rel in rels:
                    rel_uri = self.getRelURI(one_rel)
                    one_path_query += rel_uri + "|^"+rel_uri +"|"

                one_path_query = one_path_query[:-1] # remove the last | 
                one_path_query +=")"
            path_query+=one_path_query+"/"

            path_query = path_query[:-1]
            path_query +=" ?target." ## remove the last / 
            
            query = f"""
            SELECT ?target
            WHERE {{
                BIND(<{node_id}> AS ?startNode)
                {path_query}
            }}
            """
    #         print(query)
            results = self.g.query(query)
        
            for row in results:
                print(str(row['target'].toPython()))
                graph.append({
                    "source_entity": node_id, 
                    "target_entity": str(row['target'].toPython()),
                    "target_class": target,
                    "source_class": node_class
                })
        return graph 
        
    def getNetworkData(self):
        class2URI = {
            'Dataset': "http://vivoweb.org/ontology/core#Dataset",
            'Best Practices And Mandates': 'http://www.sdsconsortium.org/schemas/sds-okn.owl#BestPracticesAndMandates',
            'Infrastructure': 'https://raw.githubusercontent.com/adhollander/FSLschemas/main/sustsource.owl#Infrastructure',
            'Organization': 'http://xmlns.com/foaf/0.1/Organization',
            'Person': 'http://xmlns.com/foaf/0.1/Person',
            'Program': 'http://vivoweb.org/ontology/core#Program',
            'Project': 'http://vivoweb.org/ontology/core#Project',
            'Issue': 'http://purl.obolibrary.org/obo/BFO_0000023',
            'Tool': 'http://www.sdsconsortium.org/schemas/sds-okn.owl#Tool'
        }
        URI2class = {value: key for key, value in class2URI.items()}
        target_class = []
        for ele in self.mappedEntities:
            if ele['type']=='target':
                target_class += ele['class']
        target_class = list(set(target_class))

        for idx in self.relevantEntId:
            print(idx)
            node_id = self.data.iloc[idx]['entity'] ## current enitty id
            node_class_uri = self.data.iloc[idx]['type'] ## current entity type 
            node_class = URI2class[node_class_uri] ## 
            print(node_class, target_class, node_id)
            small_graph = self.getTargetEntities(node_class, target_class, node_id)
            # return "test"
            print(small_graph)

# %%
t = Test()

# %%
t.getNetworkData()
# Out:
# 5134
# Program ['Person'] https://raw.githubusercontent.com/adhollander/FSLschemas/main/CA_PPODterms.ttl#prg_c46c0b
# ['Program', 'GuidelineMandate', 'Role', 'Person']
# []
# 4982
# Program ['Person'] https://raw.githubusercontent.com/adhollander/FSLschemas/main/CA_PPODterms.ttl#prg_24edc1
# ['Program', 'GuidelineMandate', 'Role', 'Person']
# []
# 5021
# Program ['Person'] https://raw.githubusercontent.com/adhollander/FSLschemas/main/CA_PPODterms.ttl#prg_528218
# ['Program', 'GuidelineMandate', 'Role', 'Person']
# []
# 5043
# Program ['Person'] https://raw.githubusercontent.com/adhollander/FSLschemas/main/CA_PPODterms.ttl#prg_6b64d7
# ['Program', 'GuidelineMandate', 'Role', 'Person']
# []
# 5648
# Project ['Person'] https://raw.githubusercontent.com/adhollander/FSLschemas/main/CA_PPODterms.ttl#prj_65ae80
# ['Project', 'Organization', 'GuidelineMandate', 'Role', 'Person']
# []
